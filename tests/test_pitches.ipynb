# %%
from imagewriter.widgets import ControlPanel

from interactive import test_pitches

control = ControlPanel()
control
# Out:
# ControlPanel(children=(VBox(children=(HTML(value='<h3>Serial Connection</h3>'), SerialWidget(children=(SerialP…

# %%
test_pitches(control)
# Out:
# ✅ "Attributes test"

# %%
# control.port.rts = False
# time.sleep(0.1)
# control.port.rts = True

# %%
# control.close_port()
